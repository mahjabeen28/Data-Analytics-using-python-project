# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Expenses_tracker_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Expenses = [100, 260, 400, 150]

Total = sum (Expenses)

print("Expenses:", Expenses)
print("Total Expenses:", Total)
# Out:
# Expenses: [100, 260, 400, 150]
# Total Expenses: 910
