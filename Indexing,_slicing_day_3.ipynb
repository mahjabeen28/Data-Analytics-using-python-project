# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Indexing%2C_slicing_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array([60, 75, 48, 66, 90])

print(marks[4])
# Out:
# 90

# %%
import numpy as np

marks = np.array([70, 88, 58, 98, 77])

print(marks[0:4])
# Out:
# [70 88 58 98]
