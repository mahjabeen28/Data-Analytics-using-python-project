# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Aggregation_func_day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array([48,60,80,78,92])

average = np.mean(marks)

print(average)
# Out:
# 71.6

# %%
import numpy as np

marks = np.array([50,90,84,78,92])

average = np.median(marks)

print(average)
# Out:
# 84.0
