# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Product_sales_performance_analysis_day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
products = ["Laptop","Mobile", "Tablet", "Headphone", "SmartWatch"]

sales = np.array ([100, 200, 400, 450, 80])

print("Total Sales:", np.sum(sales))
print("Average Sales:", np.mean(sales))
print("Highest Sales:", np.max(sales))
print("Lowest sales:", np.min(sales))
# Out:
# Total Sales: 1230
# Average Sales: 246.0
# Highest Sales: 450
# Lowest sales: 80
