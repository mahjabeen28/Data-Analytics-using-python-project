# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Reshape%2C_Transpose_day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.array([1,2,3,4,5,6])

new_arr = arr.reshape(2,3)

print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]
