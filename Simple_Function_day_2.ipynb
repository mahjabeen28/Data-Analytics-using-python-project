# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Simple_Function_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hi Internship Students")
greet()
# Out:
# Hi Internship Students

# %%
def greet(name):
  print("Welcome", name)
greet("Vino")
# Out:
# Welcome Vino

# %%
def add(a, b):
  return a+b

result = add (10,40)
print("Sum=", result)
# Out:
# Sum= 50
