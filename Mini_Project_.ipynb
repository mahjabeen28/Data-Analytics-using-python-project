# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Mini_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# E-Commerce Sales Analysis

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

data = {
     "Sale_ID": [1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020],
     "Date": ["2026-05-01","2026-05-02","2026-05-03","2026-05-04","2026-05-05","2026-05-06","2026-05-07","2026-05-08","2026-05-09","2026-05-10","2026-05-11","2026-05-12","2026-05-13","2026-05-14","2026-05-15","2026-05-16","2026-05-17","2026-05-18","2026-05-19","2026-05-20"],
     "Product": ["Smartwatch","Laptop","Smartphone","Smartphone","Smartwatch","Smartwatch","Tablet","Laptop","Headphones","Laptop","Smartphone","Headphones","Laptop","Laptop","Smartwatch","Headphones","Smartphone","Headphones","Tablet","Laptop"],
     "Category": ["Accessories","Electronics","Electronics","Electronics","Accessories","Accessories","Electronics","Electronics","Accessories","Electronics","Electronics","Accessories","Electronics","Electronics","Accessories","Accessories","Electronics","Accessories","Electronics","Electronics"],
     "Quantity": [5,4,2,1,5,2,1,1,5,4,5,4,3,5,2,3,5,4,5,3],
     "Unit_Price": [150,800,500,500,150,150,300,800,50,800,500,50,800,800,150,50,500,50,300,800],
     "Total_Amount": [750,3200,1000,500,750,300,300,800,250,3200,2500,200,2400,4000,300,150,2500,200,1500,2400],
     "Region": ["North","South","East","West","North","South","East","West","North","South","East","West","North","South","East","West","North","South","East","West"],
     "Payment_Method": ["Credit Card","UPI","Cash","Credit Card","UPI","Cash","Credit Card","UPI","Cash","Credit Card","UPI","Cash","Credit Card","UPI","Cash","Credit Card","UPI","Cash","Credit Card","UPI"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Sale_ID        Date     Product     Category  Quantity  Unit_Price  \
# 0      1001  2026-05-01  Smartwatch  Accessories         5         150
# 1      1002  2026-05-02      Laptop  Electronics         4         800
# 2      1003  2026-05-03  Smartphone  Electronics         2         500
# 3      1004  2026-05-04  Smartphone  Electronics         1         500
# 4      1005  2026-05-05  Smartwatch  Accessories         5         150
# 5      1006  2026-05-06  Smartwatch  Accessories         2         150
# 6      1007  2026-05-07      Tablet  Electronics         1         300
# 7      1008  2026-05-08      Laptop  Electronics         1         800
# 8      1009  2026-05-09  Headphones  Accessories         5          50
# 9      1010  2026-05-10      Laptop  Electronics         4         800
# 10     1011  2026-05-11  Smartphone  Electronics         5         500
# 11     1012  2026-05-12  Headphones  Accessories         4          50
# ...

# %%
df.head(20)
# Out:
#     Sale_ID        Date     Product     Category  Quantity  Unit_Price  \
# 0      1001  2026-05-01  Smartwatch  Accessories         5         150
# 1      1002  2026-05-02      Laptop  Electronics         4         800
# 2      1003  2026-05-03  Smartphone  Electronics         2         500
# 3      1004  2026-05-04  Smartphone  Electronics         1         500
# 4      1005  2026-05-05  Smartwatch  Accessories         5         150
# 5      1006  2026-05-06  Smartwatch  Accessories         2         150
# 6      1007  2026-05-07      Tablet  Electronics         1         300
# 7      1008  2026-05-08      Laptop  Electronics         1         800
# 8      1009  2026-05-09  Headphones  Accessories         5          50
# 9      1010  2026-05-10      Laptop  Electronics         4         800
# 10     1011  2026-05-11  Smartphone  Electronics         5         500
# 11     1012  2026-05-12  Headphones  Accessories         4          50
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sale_ID         20 non-null     int64
#  1   Date            20 non-null     object
#  2   Product         20 non-null     object
#  3   Category        20 non-null     object
#  4   Quantity        20 non-null     int64
#  5   Unit_Price      20 non-null     int64
#  6   Total_Amount    20 non-null     int64
#  7   Region          20 non-null     object
#  8   Payment_Method  20 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 1.5+ KB
# None

# %%
print(df.shape)
# Out:
# (20, 9)

# %%
print(df.isnull().sum())
# Out:
# Sale_ID           0
# Date              0
# Product           0
# Category          0
# Quantity          0
# Unit_Price        0
# Total_Amount      0
# Region            0
# Payment_Method    0
# dtype: int64

# %%
df = df.drop_duplicates()

print(df)
# Out:
#     Sale_ID        Date     Product     Category  Quantity  Unit_Price  \
# 0      1001  2026-05-01  Smartwatch  Accessories         5         150
# 1      1002  2026-05-02      Laptop  Electronics         4         800
# 2      1003  2026-05-03  Smartphone  Electronics         2         500
# 3      1004  2026-05-04  Smartphone  Electronics         1         500
# 4      1005  2026-05-05  Smartwatch  Accessories         5         150
# 5      1006  2026-05-06  Smartwatch  Accessories         2         150
# 6      1007  2026-05-07      Tablet  Electronics         1         300
# 7      1008  2026-05-08      Laptop  Electronics         1         800
# 8      1009  2026-05-09  Headphones  Accessories         5          50
# 9      1010  2026-05-10      Laptop  Electronics         4         800
# 10     1011  2026-05-11  Smartphone  Electronics         5         500
# 11     1012  2026-05-12  Headphones  Accessories         4          50
# ...

# %%
total_sales = df["Total_Amount"].sum()

print("Total Sales:", total_sales)
# Out:
# Total Sales: 27200

# %%
product_sales = df.groupby("Product")["Total_Amount"].sum()

print(product_sales)
# Out:
# Product
# Headphones      800
# Laptop        16000
# Smartphone     6500
# Smartwatch     2100
# Tablet         1800
# Name: Total_Amount, dtype: int64

# %%
product_sales.plot(kind ='bar',
                   color = ("Red","Green","Pink","blue","Orange"))

plt.title("Product Sales Analysis")

plt.xlabel("Product")

plt.ylabel("Sales")

plt.show()
