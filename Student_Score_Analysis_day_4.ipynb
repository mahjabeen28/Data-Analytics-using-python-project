# %% [markdown]
# <a href="https://colab.research.google.com/github/mahjabeen28/Data-Analytics-using-python-project/blob/main/Student_Score_Analysis_day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

scores = [57,76,58,65,98]

total = sum(scores)
average = total/len(scores)
highest = max(score)
lowest = min(scores)

print("Student Scores:",scores)
print("Total Marks:",total)
print("Average Marks:",average)
print("Highest Marks:",highest)
print("Lowest Marks:",lowest)
# Out:
# Student Scores: [57, 76, 58, 65, 98]
# Total Marks: 354
# Average Marks: 70.8
# Highest Marks: 95
# Lowest Marks: 57
